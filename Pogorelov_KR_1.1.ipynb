# %%
#!pip install numpy
#!pip install matplotlib
#!pip install pandas

# %%
#!pip list

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
#!pip install openpyxl

# %%
df = pd.read_excel('КР-1.xlsx', sheet_name='Вар (14)')

# %%
df
# Out:
#     Площадь загальна кв.м  Этаж  Количество сотрудников в штаті          Тип  \
# 0                    9.00     1                               2   Соціальний
# 1                   30.00     1                               2   Соціальний
# 2                   15.00     1                               2   Соціальний
# 3                   20.00     1                               2  Стандартний
# 4                   30.00     1                               2   Соціальний
# ..                    ...   ...                             ...          ...
# 64                  51.77     1                               6  Преміальний
# 65                  27.26     1                               4  Преміальний
# 66                 148.91     1                               2  Стандартний
# 67                  50.93     1                               3   Соціальний
# 68                  30.00     1                               3  Преміальний
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69 entries, 0 to 68
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Площадь загальна кв.м           69 non-null     float64
#  1   Этаж                            69 non-null     int64
#  2   Количество сотрудников в штаті  69 non-null     int64
#  3   Тип                             69 non-null     object
#  4   Рейтинг в гуглі                 69 non-null     float64
#  5   Количество чеков                69 non-null     float64
#  6   Средний чек                     62 non-null     float64
#  7   Офіси                           64 non-null     float64
#  8   Середній дохід населення        64 non-null     float64
#  9   Фастфуд                         69 non-null     int64
#  10  Кава на виніс                   69 non-null     int64
#  11  Піцерія                         69 non-null     int64
# ...

# %% [markdown]
# Есть пропущенные значения в показателях Средний чек, Офіси, Середній дохід населення

# %%
df['Площадь загальна кв.м'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Большинство магазинов имеют площадт до 75 кв.м.

# %%
df['Этаж'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Все магазины имеют 1 этаж

# %%
df['Рейтинг в гуглі'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Большинство магазинов имеют рейтинг в гугле 3,75 и выше

# %%
df['Количество чеков'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# В большинстве магазинов кол-во чеков менее 4000

# %%
df['Количество сотрудников в штаті'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Большинство магазинов имеет штат в 2, 4 или 6 сотрудников

# %%
df['Средний чек'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Большинство магазинов имеет чек 80-120 грн

# %%
df['Середній дохід населення'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Самый распространенный доход среди населения - 12 тыс

# %%
df['Офіси'].plot(kind = 'hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# Большинство магазинов имеет до 500 офисов

# %%
dfr = df.drop(['Этаж'], axis='columns', inplace=False)
dfr.shape
# Out:
# (69, 13)

# %%
df.describe()
# Out:
#        Площадь загальна кв.м  Этаж  Количество сотрудников в штаті  \
# count              69.000000  69.0                       69.000000
# mean               47.412725   1.0                        3.652174
# std                37.862989   0.0                        1.607209
# min                 4.000000   1.0                        2.000000
# 25%                26.720000   1.0                        2.000000
# 50%                32.300000   1.0                        4.000000
# 75%                56.240000   1.0                        4.000000
# max               232.300000   1.0                        8.000000
#
#        Рейтинг в гуглі  Количество чеков  Средний чек        Офіси  \
# count        69.000000         69.000000    62.000000    64.000000
# mean          3.810145       3021.576882    95.897581   439.875000
# std           0.695605       1904.285820    19.192685   459.930792
# min           1.800000        369.000000    65.270000     0.000000
# ...

# %% [markdown]
# В среднем магазины имеют торговую площадь 47.41 кв.м., количество чеков - 3021, а средний доход населения - 11990.42грн. Минимальные значения для каждого из значений написаны в строке "min", а максимальные соответсвенно в строке с названием "max". С помощью строки минимальных значений можно сделать вывод, что существует ошибка ввода для значений "Средний доход населения", то есть в этои столюце есть пропущенные значения.

# %%
# Mistakes Deleting
df = df.loc[df['Середній дохід населення'] > 8000]
df = df.loc[df['Рейтинг в гуглі'] > 3]

# %%
df
# Out:
#     Площадь загальна кв.м  Этаж  Количество сотрудников в штаті  \
# 1                  30.000     1                               2
# 4                  30.000     1                               2
# 5                  57.700     1                               2
# 6                  50.000     1                               4
# 7                  45.000     1                               6
# 9                  54.500     1                               2
# 10                 15.000     1                               2
# 11                 27.090     1                               5
# 12                 56.650     1                               4
# 13                 80.000     1                               8
# 14                232.300     1                               6
# 17                 51.000     1                               4
# 20                 44.000     1                               4
# 21                  4.000     1                               2
# ...

# %%
# Cheking Missing data
df.isnull().sum()
# Out:
# Площадь загальна кв.м             0
# Этаж                              0
# Количество сотрудников в штаті    0
# Тип                               0
# Рейтинг в гуглі                   0
# Количество чеков                  0
# Средний чек                       0
# Офіси                             0
# Середній дохід населення          0
# Фастфуд                           0
# Кава на виніс                     0
# Піцерія                           0
# Магістральна вулиця               0
# Стихійна торгівля                 0
# dtype: int64

# %%
df.dtypes
# Out:
# Площадь загальна кв.м             float64
# Этаж                                int64
# Количество сотрудников в штаті      int64
# Тип                                object
# Рейтинг в гуглі                   float64
# Количество чеков                  float64
# Средний чек                       float64
# Офіси                             float64
# Середній дохід населення          float64
# Фастфуд                             int64
# Кава на виніс                       int64
# Піцерія                             int64
# Магістральна вулиця                 int64
# Стихійна торгівля                   int64
# dtype: object

# %%
#!pip install sklearn

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Площадь загальна кв.м             0
# Этаж                              0
# Количество сотрудников в штаті    0
# Тип                               0
# Рейтинг в гуглі                   0
# Количество чеков                  0
# Средний чек                       0
# Офіси                             0
# Середній дохід населення          0
# Фастфуд                           0
# Кава на виніс                     0
# Піцерія                           0
# Магістральна вулиця               0
# Стихійна торгівля                 0
# dtype: int64

# %%
#!pip install seaborn

# %%
def outliers(df):
    num_var = list(df._get_numeric_data().columns)
    for col_names in num_var:
        df[col_names] = df[col_names].apply(lambda y: df[col_names].mean()-3*df[col_names].std() 
                            if y < df[col_names].mean()-3*df[col_names].std() else y)
        df[col_names] = df[col_names].apply(lambda y: df[col_names].mean()+3*df[col_names].std() 
                            if y > df[col_names].mean()+3*df[col_names].std() else y)
    return(df)

# %%
df = outliers(df)
df.describe()
# Out:
#        Площадь загальна кв.м  Этаж  Количество сотрудников в штаті  \
# count              43.000000  43.0                       43.000000
# mean               48.707644   1.0                        4.093023
# std                32.146621   0.0                        1.687686
# min                 4.000000   1.0                        2.000000
# 25%                29.635000   1.0                        2.500000
# 50%                45.200000   1.0                        4.000000
# 75%                56.445000   1.0                        6.000000
# max               166.540701   1.0                        8.000000
#
#        Рейтинг в гуглі  Количество чеков  Средний чек        Офіси  \
# count        43.000000         43.000000    43.000000    43.000000
# mean          4.193023       3463.279070    98.114543   439.607795
# std           0.301105       2102.726963    19.041362   497.745102
# min           3.400000        369.000000    65.270000     0.000000
# ...

# %%
df3 = df[['Тип']]
info = []
for column in df3.columns:
        vals = {"col": column,
                "nunique": df3[column].nunique(),
                "unique": df3[column].unique(),
                "type": df3[column].dtype
               }
        info.append(vals)
pd.DataFrame(info).sort_values(by = "col", ascending = False)
# Out:
#    col  nunique                                             unique    type
# 0  Тип        5  [Соціальний, Стандартний, Преміальний, Стандар...  object

# %%
fm = {'Соціальний':0,'Преміальний':1,'Стандартний':2,'Соціальний Плюс':3,'Стандарт Плюс':4}
df['Тип'] = df['Тип'].map(fm)
df
# Out:
#     Площадь загальна кв.м  Этаж  Количество сотрудников в штаті  Тип  \
# 1               30.000000     1                               2    0
# 4               30.000000     1                               2    0
# 5               57.700000     1                               2    2
# 6               50.000000     1                               4    1
# 7               45.000000     1                               6    1
# 9               54.500000     1                               2    4
# 10              15.000000     1                               2    0
# 11              27.090000     1                               5    1
# 12              56.650000     1                               4    1
# 13              80.000000     1                               8    1
# 14             166.540701     1                               6    1
# 17              51.000000     1                               4    2
# 20              44.000000     1                               4    2
# ...

# %%
import seaborn as sns
corrmat = dfr.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, annot=True)
plt.show()

# %%
df.describe()
# Out:
#        Площадь загальна кв.м  Этаж  Количество сотрудников в штаті        Тип  \
# count              43.000000  43.0                       43.000000  43.000000
# mean               48.707644   1.0                        4.093023   1.069767
# std                32.146621   0.0                        1.687686   0.827945
# min                 4.000000   1.0                        2.000000   0.000000
# 25%                29.635000   1.0                        2.500000   1.000000
# 50%                45.200000   1.0                        4.000000   1.000000
# 75%                56.445000   1.0                        6.000000   1.000000
# max               166.540701   1.0                        8.000000   4.000000
#
#        Рейтинг в гуглі  Количество чеков  Средний чек        Офіси  \
# count        43.000000         43.000000    43.000000    43.000000
# mean          4.193023       3463.279070    98.114543   439.607795
# ...

# %%
import seaborn as sns
corrmat = dfr.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, annot=True)
plt.show()

# %%
# Splitting the dataset into the Training set and Test set
df.shape
# Out:
# (43, 14)

# %%
X = df.iloc[:, [True,True,True,True,True,False,True,True,True,True,True,True,True,True]]
y = df['Количество чеков']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=10)
X
# Out:
#     Площадь загальна кв.м  Этаж  Количество сотрудников в штаті  Тип  \
# 1               30.000000     1                               2    0
# 4               30.000000     1                               2    0
# 5               57.700000     1                               2    2
# 6               50.000000     1                               4    1
# 7               45.000000     1                               6    1
# 9               54.500000     1                               2    4
# 10              15.000000     1                               2    0
# 11              27.090000     1                               5    1
# 12              56.650000     1                               4    1
# 13              80.000000     1                               8    1
# 14             166.540701     1                               6    1
# 17              51.000000     1                               4    2
# 20              44.000000     1                               4    2
# ...

# %%
#!pip install statsmodels

# %%
from sklearn.linear_model import LinearRegression

# %%
mr = LinearRegression().fit(X_train, y_train)

# Coefficient of determination R^2
mr.score(X_train, y_train).round(3)
# Out:
# 0.768

# %% [markdown]
# 0.768 - Коэффициент детерминации

# %%
from sklearn.linear_model import LinearRegression

# %%
mr = LinearRegression().fit(X_train, y_train)

# Getting parameters
mr.coef_, mr.intercept_
# Out:
# (array([-4.65317252e+00, -9.61488666e-11,  8.42399322e+02,  3.60950491e+00,
#          1.45816936e+03, -9.84815078e-01, -2.78044749e-01, -2.53995005e-01,
#          1.01378526e+03,  4.85451570e+02,  5.59719796e+02,  1.58283945e+02,
#         -1.80057536e+02]),
#  -2865.006166842035)

# %%
f1 = df['Количество чеков']

# %%
from sklearn.linear_model import LinearRegression
mr = LinearRegression().fit(X_train[f1], y_train)

mr.coef_, mr.intercept_
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-9b3d54b00c77> in <module>
#       1 from sklearn.linear_model import LinearRegression
# ----> 2 mr = LinearRegression().fit(X_train[f1], y_train)
#       3
#       4 mr.coef_, mr.intercept_
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# ...
